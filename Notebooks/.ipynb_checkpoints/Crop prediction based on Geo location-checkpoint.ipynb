# %%
import numpy as np
import pandas as pd
#import geopandas as gpd

from matplotlib import pyplot as plt

# %%
df1 = pd.read_csv(filepath_or_buffer="C:\\Users\\santh\\Downloads\\csv")
df1
# Out:
#                     state        district      market              commodity  \
# 0     Andaman and Nicobar   South Andaman  Port Blair             Amaranthus
# 1     Andaman and Nicobar   South Andaman  Port Blair         Banana - Green
# 2     Andaman and Nicobar   South Andaman  Port Blair  Bhindi(Ladies Finger)
# 3     Andaman and Nicobar   South Andaman  Port Blair           Bitter gourd
# 4     Andaman and Nicobar   South Andaman  Port Blair           Black pepper
# ...                   ...             ...         ...                    ...
# 2233          West Bengal  Uttar Dinajpur    Islampur                 Potato
# 2234          West Bengal  Uttar Dinajpur    Islampur                   Rice
# 2235          West Bengal  Uttar Dinajpur     Raiganj                   Jute
# 2236          West Bengal  Uttar Dinajpur     Raiganj                   Rice
# 2237          West Bengal  Uttar Dinajpur     Raiganj                  Wheat
#
# ...

# %%
len(df1[df1["commodity"]=="Cotton"])
# Out:
# 23

# %%
df3 = pd.read_csv("C:\\Users\\santh\\Downloads\\Crop_recommendation (2).csv")
df3
# Out:
#         N   P   K  temperature   humidity        ph    rainfall   label
# 0      90  42  43    20.879744  82.002744  6.502985  202.935536    rice
# 1      85  58  41    21.770462  80.319644  7.038096  226.655537    rice
# 2      60  55  44    23.004459  82.320763  7.840207  263.964248    rice
# 3      74  35  40    26.491096  80.158363  6.980401  242.864034    rice
# 4      78  42  42    20.130175  81.604873  7.628473  262.717340    rice
# ...   ...  ..  ..          ...        ...       ...         ...     ...
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507  coffee
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610  coffee
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839  coffee
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293  coffee
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041  coffee
#
# [2200 rows x 8 columns]

# %%
df1["commodity"] = df["commodity"].replace(["Rice","Papaya","Water Melon","Karbuja(Musk Melon)","Apple","Orange","Coconut","Jute","Grapes","Mango","Banana","Pomegranate","Lentil (Masur)(Whole)","Black Gram (Urd Beans)(Whole)","Maize","Green Gram (Moong)(Whole)","Moath Dal","Tomato","Cotton","Pegeon Pea (Arhar Fali)","Niger Seed (Ramtil)","Bengal Gram Dal (Chana Dal)"],
                                           ["rice","papaya","watermelon","muskmelon","apple","orange","coconut","jute","grapes","mango","banana","pomegranate","lentil","blackgram","maize","mungbean","mothbeans","coffee","cotton","pigeonpeas","kidneybeans","chickpea"])
# Out:
# C:\Users\santh\AppData\Local\Temp/ipykernel_25052/1252255824.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[df1["commodity"]=="Cotton"]["commodity"] = "rice"

# %%
df3["label"] = df3["label"].replace( ["rice","papaya","watermelon","muskmelon","apple","orange","coconut","jute","grapes","mango","banana","pomegranate","lentil","blackgram","maize","mungbean","mothbeans","coffee","cotton","pigeonpeas","kidneybeans","chickpea"],["Rice","Papaya","Water Melon","Karbuja(Musk Melon)","Apple","Orange","Coconut","Jute","Grapes","Mango","Banana","Pomegranate","Lentil (Masur)(Whole)","Black Gram (Urd Beans)(Whole)","Maize","Green Gram (Moong)(Whole)","Moath Dal","Tomato","Cotton","Pegeon Pea (Arhar Fali)","Niger Seed (Ramtil)","Bengal Gram Dal (Chana Dal)"])

# %%
Crops = df3["label"].unique()
Crops
# Out:
# array(['Rice', 'Maize', 'Bengal Gram Dal (Chana Dal)',
#        'Niger Seed (Ramtil)', 'Pegeon Pea (Arhar Fali)', 'Moath Dal',
#        'Green Gram (Moong)(Whole)', 'Black Gram (Urd Beans)(Whole)',
#        'Lentil (Masur)(Whole)', 'Pomegranate', 'Banana', 'Mango',
#        'Grapes', 'Water Melon', 'Karbuja(Musk Melon)', 'Apple', 'Orange',
#        'Papaya', 'Coconut', 'Cotton', 'Jute', 'Tomato'], dtype=object)

# %%
df1[df1["commodity"].isin(Crops)]
# Out:
#                     state            district             market  \
# 11    Andaman and Nicobar       South Andaman         Port Blair
# 15         Andhra Pradesh             Chittor           Kalikiri
# 16         Andhra Pradesh             Chittor    Mulakalacheruvu
# 17         Andhra Pradesh             Chittor         Vayalapadu
# 22                  Assam              Cachar             Cachar
# ...                   ...                 ...                ...
# 2231          West Bengal  Sounth 24 Parganas  Baruipur(Canning)
# 2232          West Bengal      Uttar Dinajpur           Islampur
# 2234          West Bengal      Uttar Dinajpur           Islampur
# 2235          West Bengal      Uttar Dinajpur            Raiganj
# 2236          West Bengal      Uttar Dinajpur            Raiganj
#
#                   commodity    variety arrival_date  min_price  max_price  \
# 11                  Coconut        Big   04/03/2019       5400       6000
# ...

# %%
df1[df1["commodity"]=="Cotton"]
# Out:
#                state          district            market commodity  \
# 125          Gujarat       Panchmahals           Gogamba    Cotton
# 163          Gujarat  Vadodara(Baroda)            Bodeli    Cotton
# 164          Gujarat  Vadodara(Baroda)     Bodeli(Hadod)    Cotton
# 165          Gujarat  Vadodara(Baroda)  Bodeli(Kalediya)    Cotton
# 166          Gujarat  Vadodara(Baroda)   Bodeli(Modasar)    Cotton
# 707   Madhya Pradesh            Jhabua           Thandla    Cotton
# 727      Maharashtra          Buldhana    Deoulgaon Raja    Cotton
# 730      Maharashtra           Jalgaon             Yawal    Cotton
# 749      Maharashtra            Nagpur            Savner    Cotton
# 1144          Punjab             Mansa             Mansa    Cotton
# 1161          Punjab           Muktsar            Malout    Cotton
# 1295      Tamil Nadu        Dharmapuri      Papparapatti    Cotton
# 1323      Tamil Nadu       Krishnagiri        Uthangarai    Cotton
# ...

# %%
df2 = pd.read_csv("C:\\Users\\santh\\Downloads\\district wise rainfall normal.csv")
df2
# Out:
#                    STATE_UT_NAME        DISTRICT    JAN   FEB    MAR    APR  \
# 0    ANDAMAN And NICOBAR ISLANDS         NICOBAR  107.3  57.9   65.2  117.0
# 1    ANDAMAN And NICOBAR ISLANDS   SOUTH ANDAMAN   43.7  26.0   18.6   90.5
# 2    ANDAMAN And NICOBAR ISLANDS   N & M ANDAMAN   32.7  15.9    8.6   53.4
# 3              ARUNACHAL PRADESH           LOHIT   42.2  80.8  176.4  358.5
# 4              ARUNACHAL PRADESH      EAST SIANG   33.3  79.5  105.9  216.5
# ..                           ...             ...    ...   ...    ...    ...
# 636                       KERALA          IDUKKI   13.4  22.1   43.6  150.4
# 637                       KERALA        KASARGOD    2.3   1.0    8.4   46.9
# 638                       KERALA  PATHANAMTHITTA   19.8  45.2   73.9  184.9
# 639                       KERALA         WAYANAD    4.8   8.3   17.5   83.3
# 640                  LAKSHADWEEP     LAKSHADWEEP   20.8  14.7   11.8   48.9
#
# ...

# %%
len(df2["DISTRICT"].unique())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'commodity'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df2[df2["DISTRICT"]=="NICOBAR"]["Jan-Feb"]/2
# Out:
# 0    82.6
# Name: Jan-Feb, dtype: float64

# %%
df3 = pd.read_csv("C:\\Users\\santh\\Downloads\\Crop_recommendation (2).csv")
df3["label"].unique()
# Out:
# array(['rice', 'maize', 'chickpea', 'kidneybeans', 'pigeonpeas',
#        'mothbeans', 'mungbean', 'blackgram', 'lentil', 'pomegranate',
#        'banana', 'mango', 'grapes', 'watermelon', 'muskmelon', 'apple',
#        'orange', 'papaya', 'coconut', 'cotton', 'jute', 'coffee'],
#       dtype=object)

# %%
df3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_25052/3214400566.py in <module>
#       1 df3
# ----> 2 list = list()
#
# TypeError: 'numpy.ndarray' object is not callable

# %%
val = "NICOBAR"
option = "Jan-Feb"

# %%
dataset = df3.to_numpy()
dataset
test_jan_feb = df2[df2["DISTRICT"]==val][option].to_numpy()
test = test_jan_feb/2
test
# Out:
# array([82.6])

# %%
from math import sqrt
 
# calculate the Euclidean distance between two vectors
def euclidean_distance(row1, row2):
    distance = (row1[0]-row2[6])**2
    return sqrt(distance)
 
# Locate the most similar neighbors
def get_neighbors(train, test_row, num_neighbors):
    distances = list()
    for train_row in train:
        #print(train_row)
        dist = euclidean_distance(test_row, train_row)
        distances.append((train_row, dist))
    distances.sort(key=lambda tup: tup[1])
    #print(distances)
    neighbors = list()
    for i in range(num_neighbors):
        neighbors.append(distances[i][0])
    return neighbors
 
neighbors = get_neighbors(dataset, test, 100)
pred=[]
print(test)
for neighbor in neighbors:
    pred.append(neighbor[-1])

print(pred)
#print(np.unique(pred))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_25052/3035147120.py in <module>
#      20     return neighbors
#      21
# ---> 22 neighbors = get_neighbors(dataset, test, 100)
#      23 pred=[]
#      24 print(test)
#
# ~\AppData\Local\Temp/ipykernel_25052/3035147120.py in get_neighbors(train, test_row, num_neighbors)
#       8 # Locate the most similar neighbors
#       9 def get_neighbors(train, test_row, num_neighbors):
# ---> 10     distances = list()
#      11     for train_row in train:
#      12         #print(train_row)
#
# TypeError: 'numpy.ndarray' object is not callable

# %%
df1[df1["commodity"]==pred[0]]
# Out:
#               state     district     market                    commodity  \
# 888         Manipur    Bishnupur  Bishenpur  Bengal Gram Dal (Chana Dal)
# 917         Manipur  Imphal West     Imphal  Bengal Gram Dal (Chana Dal)
# 928         Manipur      Thoubal    Thoubal  Bengal Gram Dal (Chana Dal)
# 1865  Uttar Pradesh     Mirzapur   Mirzapur  Bengal Gram Dal (Chana Dal)
#
#               variety arrival_date  min_price  max_price  modal_price
# 888   Bengal Gram Dal   04/03/2019          0       9600         9600
# 917   Bengal Gram Dal   04/03/2019          0       8000         8000
# 928   Bengal Gram Dal   04/03/2019          0      11000        11000
# 1865  Bengal Gram Dal   04/03/2019       5400       5470         5430

# %%
pred[2]
# Out:
# 'Niger Seed (Ramtil)'

# %%
df1[df1["commodity"]==pred[1]]
# Out:
#               state     district     market                    commodity  \
# 888         Manipur    Bishnupur  Bishenpur  Bengal Gram Dal (Chana Dal)
# 917         Manipur  Imphal West     Imphal  Bengal Gram Dal (Chana Dal)
# 928         Manipur      Thoubal    Thoubal  Bengal Gram Dal (Chana Dal)
# 1865  Uttar Pradesh     Mirzapur   Mirzapur  Bengal Gram Dal (Chana Dal)
#
#               variety arrival_date  min_price  max_price  modal_price
# 888   Bengal Gram Dal   04/03/2019          0       9600         9600
# 917   Bengal Gram Dal   04/03/2019          0       8000         8000
# 928   Bengal Gram Dal   04/03/2019          0      11000        11000
# 1865  Bengal Gram Dal   04/03/2019       5400       5470         5430
